# %%
import pandas as pd

# %% [markdown]
# ## You need to run notebooks 1 and 2, to populate your local datastore.  The datafiles are ignored when commiting to Git.

# %%
file_name = '1.2 Energy'
all_items = pd.read_pickle(f'datastore/processed_data/not_seasonally_adjusted/{file_name}.pickle')
all_items.tail()
# Out:
#                                                  series_title    value  \
# date
# 2021-10-31  Energy in U.S. city average, all urban consume...  255.338
# 2021-11-30  Energy in U.S. city average, all urban consume...  259.100
# 2021-12-31  Energy in U.S. city average, all urban consume...  256.207
# 2022-01-31  Energy in U.S. city average, all urban consume...  260.653
# 2022-02-28  Energy in U.S. city average, all urban consume...  267.771
#
#             yoy_inflation_rate  mom_inflation_rate
# date
# 2021-10-31            0.299708            0.028643
# 2021-11-30            0.332901            0.014733
# 2021-12-31            0.292963           -0.011166
# 2022-01-31            0.269787            0.017353
# 2022-02-28            0.255508            0.027308

# %%
all_items['yoy_inflation_rate'].plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
all_items['mom_inflation_rate'].plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
all_items['yoy_inflation_rate'].hist()
# Out:
# <AxesSubplot:>
