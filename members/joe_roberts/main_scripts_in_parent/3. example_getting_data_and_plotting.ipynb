# %%
import pandas as pd

# %% [markdown]
# ## You need to run notebooks 1 and 2, to populate your local datastore.  The datafiles are ignored when commiting to Git.

# %%
file_name = '1. All Items'
all_items = pd.read_pickle(f'datastore/processed_data/not_seasonally_adjusted/{file_name}.pickle')
all_items.tail()
# Out:
#                                                  series_title    value  \
# date
# 2021-10-31  All items in U.S. city average, all urban cons...  276.589
# 2021-11-30  All items in U.S. city average, all urban cons...  277.948
# 2021-12-31  All items in U.S. city average, all urban cons...  278.802
# 2022-01-31  All items in U.S. city average, all urban cons...  281.148
# 2022-02-28  All items in U.S. city average, all urban cons...  283.716
#
#             yoy_inflation_rate  mom_inflation_rate
# date
# 2021-10-31            0.062219            0.008308
# 2021-11-30            0.068090            0.004913
# 2021-12-31            0.070364            0.003073
# 2022-01-31            0.074799            0.008415
# 2022-02-28            0.078711            0.009134

# %%
all_items['yoy_inflation_rate'].plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
all_items['mom_inflation_rate'].plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
all_items['yoy_inflation_rate'].hist()
# Out:
# <AxesSubplot:>
