# %%
import pandas as pd
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt

# %%
file_name = '1. All Items'
all_items = pd.read_pickle(f'datastore/processed_data/not_seasonally_adjusted/{file_name}.pickle')

# %%
pd.set_option('display.max_rows', 1000)
pd.options.display.float_format = '{:,.2f}'.format
# %matplotlib inline
plt.rcParams["figure.figsize"] = (10,5)

# %%
file_name = '1.1 Food'
food = pd.read_pickle(f'datastore/processed_data/not_seasonally_adjusted/{file_name}.pickle')
food.tail()
# Out:
#                                                  series_title  value  \
# date
# 2021-11-30  Food in U.S. city average, all urban consumers... 285.51
# 2021-12-31  Food in U.S. city average, all urban consumers... 286.97
# 2022-01-31  Food in U.S. city average, all urban consumers... 289.77
# 2022-02-28  Food in U.S. city average, all urban consumers... 292.79
# 2022-03-31  Food in U.S. city average, all urban consumers... 295.73
#
#             yoy_inflation_rate  mom_inflation_rate
# date
# 2021-11-30                0.06                0.00
# 2021-12-31                0.06                0.01
# 2022-01-31                0.07                0.01
# 2022-02-28                0.08                0.01
# 2022-03-31                0.09                0.01

# %%
food.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1311 entries, 1913-01-31 to 2022-03-31
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   series_title        1311 non-null   object
#  1   value               1311 non-null   float64
#  2   yoy_inflation_rate  1299 non-null   float64
#  3   mom_inflation_rate  1310 non-null   float64
# dtypes: float64(3), object(1)
# memory usage: 51.2+ KB

# %%
food.isnull().sum()
# Out:
# series_title           0
# value                  0
# yoy_inflation_rate    12
# mom_inflation_rate     1
# dtype: int64

# %%
food['yoy_inflation_rate'].plot()
plt.title("Food YoY Inflation Rate")
plt.xlabel("Date")
plt.ylabel("Inflation Rate Change")
plt.axhline(y=0, color='black', linestyle='--')
plt.show()

# %%
food['mom_inflation_rate'].plot()
plt.title("Food MoM Inflation Rate")
plt.xlabel("Date")
plt.ylabel("Inflation Rate Change")
plt.axhline(y=0, color='black', linestyle='--')
plt.show()

# %%
food['yoy_inflation_rate'].hist()
plt.title("Food YoY Inflation Rate")
plt.xlabel("Inflation Rate Change")
plt.ylabel("Frequency")
plt.show()

# %%
file_name = '1.1.1 Food at Home'
food_at_home = pd.read_pickle(f'datastore/processed_data/not_seasonally_adjusted/{file_name}.pickle')
food_at_home.tail()
# Out:
#                                                  series_title  value  \
# date
# 2021-11-30  Food at home in U.S. city average, all urban c... 266.38
# 2021-12-31  Food at home in U.S. city average, all urban c... 267.56
# 2022-01-31  Food at home in U.S. city average, all urban c... 270.71
# 2022-02-28  Food at home in U.S. city average, all urban c... 274.57
# 2022-03-31  Food at home in U.S. city average, all urban c... 278.61
#
#             yoy_inflation_rate  mom_inflation_rate
# date
# 2021-11-30                0.06                0.00
# 2021-12-31                0.06                0.00
# 2022-01-31                0.07                0.01
# 2022-02-28                0.09                0.01
# 2022-03-31                0.10                0.01

# %%
food_at_home['yoy_inflation_rate'].plot()
plt.title("Food at Home YoY Inflation Rate")
plt.xlabel("Date")
plt.ylabel("Inflation Rate Change")
plt.axhline(y=0, color='black', linestyle='--')
plt.show()

# %%
food_at_home['mom_inflation_rate'].plot()
plt.title("Food at Home MoM Inflation Rate")
plt.xlabel("Date")
plt.ylabel("Inflation Rate Change")
plt.axhline(y=0, color='black', linestyle='--')
plt.show()

# %%
food_at_home['yoy_inflation_rate'].hist()
plt.title("Food at Home YoY Inflation Rate")
plt.xlabel("Inflation Rate Change")
plt.ylabel("Frequency")
plt.show()

# %%
file_name = '1.1.2 Food Away From Home'
food_away_from_home = pd.read_pickle(f'datastore/processed_data/not_seasonally_adjusted/{file_name}.pickle')
food_away_from_home.tail()
# Out:
#                                                  series_title  value  \
# date
# 2021-11-30  Food away from home in U.S. city average, all ... 315.48
# 2021-12-31  Food away from home in U.S. city average, all ... 317.37
# 2022-01-31  Food away from home in U.S. city average, all ... 319.47
# 2022-02-28  Food away from home in U.S. city average, all ... 320.88
# 2022-03-31  Food away from home in U.S. city average, all ... 321.69
#
#             yoy_inflation_rate  mom_inflation_rate
# date
# 2021-11-30                0.06                0.01
# 2021-12-31                0.06                0.01
# 2022-01-31                0.06                0.01
# 2022-02-28                0.07                0.00
# 2022-03-31                0.07                0.00

# %%
food_away_from_home['yoy_inflation_rate'].plot()
plt.title("Food away from Home YoY Inflation Rate")
plt.xlabel("Date")
plt.ylabel("Inflation Rate Change")
plt.axhline(y=0, color='black', linestyle='--')
plt.show()

# %%
food_away_from_home['mom_inflation_rate'].plot()
plt.title("Food away from Home MoM Inflation Rate")
plt.xlabel("Date")
plt.ylabel("Inflation Rate Change")
plt.axhline(y=0, color='black', linestyle='--')
plt.show()

# %%
food_away_from_home['yoy_inflation_rate'].hist()
plt.title("Food away from Home YoY Inflation Rate")
plt.xlabel("Inflation Rate Change")
plt.ylabel("Frequency")
plt.show()

# %%
plt.plot(food_at_home.mom_inflation_rate, color = 'red', label = 'Food at Home')
plt.plot(food_away_from_home.mom_inflation_rate, color = 'blue', label = 'Food away from Home')

plt.title("Month over Month Change in Inflation Rate")
plt.xlabel("Date")
plt.ylabel("% Change")
plt.axhline(y=0, color='black', linestyle='--')

plt.tight_layout(pad=1)
plt.legend()
plt.show()

# %%
plt.plot(food_at_home.yoy_inflation_rate, color = 'red', label = 'Food at Home')
plt.plot(food_away_from_home.yoy_inflation_rate, color = 'blue', label = 'Food away from Home')

plt.title("Year over Year Change in Inflation Rate")
plt.xlabel("Date")
plt.ylabel("% Change")
plt.axhline(y=0, color='black', linestyle='--')

plt.tight_layout(pad=1)
plt.legend()
plt.show()

# %%
plt.plot(food_at_home.yoy_inflation_rate, color = 'green', label = 'Food at Home')
plt.plot(food_away_from_home.yoy_inflation_rate, color = 'blue', label = 'Food away from Home')
plt.plot(food.yoy_inflation_rate, color = 'purple', label = "Food" )

plt.title("Year over Year Change in Inflation Rate")
plt.xlabel("Date")
plt.ylabel("% Change")
plt.axhline(y=0, color='black', linestyle='--')

plt.tight_layout(pad=1)
plt.legend()
plt.show()

# %%
file_name = '1.1.1.1 Meats, Poultry, Fish, and Eggs'
meats_fish_eggs = pd.read_pickle(f'datastore/processed_data/not_seasonally_adjusted/{file_name}.pickle')
meats_fish_eggs.tail()
# Out:
#                                                  series_title  value  \
# date
# 2021-11-30  Meats, poultry, fish, and eggs in U.S. city av... 299.23
# 2021-12-31  Meats, poultry, fish, and eggs in U.S. city av... 297.60
# 2022-01-31  Meats, poultry, fish, and eggs in U.S. city av... 298.44
# 2022-02-28  Meats, poultry, fish, and eggs in U.S. city av... 301.24
# 2022-03-31  Meats, poultry, fish, and eggs in U.S. city av... 305.12
#
#             yoy_inflation_rate  mom_inflation_rate
# date
# 2021-11-30                0.13                0.01
# 2021-12-31                0.13               -0.01
# 2022-01-31                0.12                0.00
# 2022-02-28                0.13                0.01
# 2022-03-31                0.14                0.01

# %%
meats_fish_eggs['yoy_inflation_rate'].plot()
plt.title("Meats, Poultry, Fish, and Eggs YoY Inflation Rate")
plt.xlabel("Date")
plt.ylabel("Inflation Rate Change")
plt.axhline(y=0, color='black', linestyle='--')
plt.show()

# %%
meats_fish_eggs['mom_inflation_rate'].plot()
plt.title("Meats, Poultry, Fish, and Eggs MoM Inflation Rate")
plt.xlabel("Date")
plt.ylabel("Inflation Rate Change")
plt.axhline(y=0, color='black', linestyle='--')

plt.show()

# %%
file_name = '1.1.1.2 Fruits and Vegetables'
fruits_veggies = pd.read_pickle(f'datastore/processed_data/not_seasonally_adjusted/{file_name}.pickle')
fruits_veggies.tail()
# Out:
#                                                  series_title  value  \
# date
# 2021-11-30  Fruits and vegetables in U.S. city average, al... 318.44
# 2021-12-31  Fruits and vegetables in U.S. city average, al... 321.93
# 2022-01-31  Fruits and vegetables in U.S. city average, al... 327.45
# 2022-02-28  Fruits and vegetables in U.S. city average, al... 333.68
# 2022-03-31  Fruits and vegetables in U.S. city average, al... 337.50
#
#             yoy_inflation_rate  mom_inflation_rate
# date
# 2021-11-30                0.04                0.00
# 2021-12-31                0.05                0.01
# 2022-01-31                0.06                0.02
# 2022-02-28                0.08                0.02
# 2022-03-31                0.08                0.01

# %%
fruits_veggies['yoy_inflation_rate'].plot()
plt.title("Fruits and Vegetables YoY Inflation Rate")
plt.xlabel("Date")
plt.ylabel("Inflation Rate Change")
plt.axhline(y=0, color='black', linestyle='--')
plt.show()

# %%
fruits_veggies['mom_inflation_rate'].plot()
plt.title("Fruits and Vegetables MoM Inflation Rate")
plt.xlabel("Date")
plt.ylabel("Inflation Rate Change")
plt.axhline(y=0, color='black', linestyle='--')
plt.show()

# %%
file_name = '1.1.1.3 Cereals and Bakery Products'
cereal_bakery = pd.read_pickle(f'datastore/processed_data/not_seasonally_adjusted/{file_name}.pickle')
cereal_bakery.tail()
# Out:
#                                                  series_title  value  \
# date
# 2021-11-30  Cereals and bakery products in U.S. city avera... 295.91
# 2021-12-31  Cereals and bakery products in U.S. city avera... 297.28
# 2022-01-31  Cereals and bakery products in U.S. city avera... 302.24
# 2022-02-28  Cereals and bakery products in U.S. city avera... 306.19
# 2022-03-31  Cereals and bakery products in U.S. city avera... 311.61
#
#             yoy_inflation_rate  mom_inflation_rate
# date
# 2021-11-30                0.05                0.00
# 2021-12-31                0.05                0.00
# 2022-01-31                0.07                0.02
# 2022-02-28                0.08                0.01
# 2022-03-31                0.09                0.02

# %%
cereal_bakery['yoy_inflation_rate'].plot()
plt.title("Cereals and Bakery Products YoY Inflation Rate")
plt.xlabel("Date")
plt.ylabel("Inflation Rate Change")
plt.axhline(y=0, color='black', linestyle='--')
plt.show()

# %%
cereal_bakery['mom_inflation_rate'].plot()
plt.title("Cereals and Bakery Products MoM Inflation Rate")
plt.xlabel("Date")
plt.ylabel("Inflation Rate Change")
plt.axhline(y=0, color='black', linestyle='--')
plt.show()

# %%
plt.plot(meats_fish_eggs.yoy_inflation_rate, color = 'green', label = 'Meats, Poultry, Fish, and Eggs')
plt.plot(fruits_veggies.yoy_inflation_rate, color = 'blue', label = 'Fruits and Vegetables')
plt.plot(cereal_bakery.yoy_inflation_rate, color = 'purple', label = 'Cereals and Bakery Products')

plt.title("Year over Year Change in Inflation Rate")
plt.xlabel("Date")
plt.ylabel("% Change")
plt.axhline(y=0, color='gray', linestyle='--')

plt.tight_layout(pad=1)
plt.legend()
plt.show()

# %%
plt.plot(meats_fish_eggs.yoy_inflation_rate, color = 'green', label = 'Meats, Poultry, Fish, and Eggs')
plt.plot(fruits_veggies.yoy_inflation_rate, color = 'blue', label = 'Fruits and Vegetables')
plt.plot(cereal_bakery.yoy_inflation_rate, color = 'purple', label = 'Cereals and Bakery Products')
plt.plot(food_at_home.yoy_inflation_rate, color = 'black', label = 'Food at Home')

plt.title("Year over Year Change in Inflation Rate")
plt.xlabel("Date")
plt.ylabel("% Change")
plt.axhline(y=0, color='gray', linestyle='--')

plt.tight_layout(pad=1)
plt.legend()
plt.show()

# %%
plt.plot(cereal_bakery.yoy_inflation_rate, color = 'purple', label = 'Cereals and Bakery Products')
plt.plot(food_at_home.yoy_inflation_rate, color = 'black', label = 'Food at Home')
#plt.plot(fruits_veggies.yoy_inflation_rate, color = 'blue', label = 'Fruits and Vegetables')
#plt.plot(meats_fish_eggs.yoy_inflation_rate, color = 'green', label = 'Meats, Poultry, Fish, and Eggs')

plt.title("Year over Year Change in Inflation Rate")
plt.xlabel("Date")
plt.ylabel("% Change")
plt.axhline(y=0, color='gray', linestyle='--')

plt.tight_layout(pad=1)
plt.legend()
plt.show()

# %%
file_name = '1.1.2.1 Full Service Meals and Snacks'
full_service_meals = pd.read_pickle(f'datastore/processed_data/not_seasonally_adjusted/{file_name}.pickle')
full_service_meals.tail()
# Out:
#                                                  series_title  value  \
# date
# 2021-11-30  Full service meals and snacks in U.S. city ave... 194.88
# 2021-12-31  Full service meals and snacks in U.S. city ave... 196.45
# 2022-01-31  Full service meals and snacks in U.S. city ave... 197.81
# 2022-02-28  Full service meals and snacks in U.S. city ave... 199.08
# 2022-03-31  Full service meals and snacks in U.S. city ave... 200.50
#
#             yoy_inflation_rate  mom_inflation_rate
# date
# 2021-11-30                0.06                0.00
# 2021-12-31                0.07                0.01
# 2022-01-31                0.07                0.01
# 2022-02-28                0.07                0.01
# 2022-03-31                0.08                0.01

# %%
file_name = '1.1.2.2 Limited Service Meals and Snacks'
limited_service_meals = pd.read_pickle(f'datastore/processed_data/not_seasonally_adjusted/{file_name}.pickle')
limited_service_meals.tail()
# Out:
#                                                  series_title  value  \
# date
# 2021-11-30  Limited service meals and snacks in U.S. city ... 209.48
# 2021-12-31  Limited service meals and snacks in U.S. city ... 210.80
# 2022-01-31  Limited service meals and snacks in U.S. city ... 212.19
# 2022-02-28  Limited service meals and snacks in U.S. city ... 212.75
# 2022-03-31  Limited service meals and snacks in U.S. city ... 212.35
#
#             yoy_inflation_rate  mom_inflation_rate
# date
# 2021-11-30                0.08                0.01
# 2021-12-31                0.08                0.01
# 2022-01-31                0.08                0.01
# 2022-02-28                0.08                0.00
# 2022-03-31                0.07               -0.00

# %%
full_service_meals['yoy_inflation_rate'].plot()
plt.title("Full Service Meals and Snacks YoY Inflation Rate")
plt.xlabel("Date")
plt.ylabel("Inflation Rate Change")
plt.axhline(y=0, color='black', linestyle='--')
plt.show()

# %%
full_service_meals['mom_inflation_rate'].plot()
plt.title("Full Service Meals and Snacks MoM Inflation Rate")
plt.xlabel("Date")
plt.ylabel("Inflation Rate Change")
plt.axhline(y=0, color='black', linestyle='--')
plt.show()

# %%
limited_service_meals['yoy_inflation_rate'].plot()
plt.title("Limited Service Meals and Snacks YoY Inflation Rate")
plt.xlabel("Date")
plt.ylabel("Inflation Rate Change")
plt.axhline(y=0, color='black', linestyle='--')
plt.show()

# %%
limited_service_meals['mom_inflation_rate'].plot()
plt.title("Limited Service Meals and Snacks MoM Inflation Rate")
plt.xlabel("Date")
plt.ylabel("Inflation Rate Change")
plt.axhline(y=0, color='black', linestyle='--')
plt.show()

# %%
plt.plot(full_service_meals.yoy_inflation_rate, color = 'red', label = 'Full Service Meals and Snacks')
plt.plot(limited_service_meals.yoy_inflation_rate, color = 'blue', label = 'Limited Service Meals and Snacks')

plt.title("Year over Year Change in Inflation Rate")
plt.xlabel("Date")
plt.ylabel("% Change")
plt.axhline(y=0, color='black', linestyle='--')

plt.tight_layout(pad=1)
plt.legend()
plt.show()

# %%
plt.plot(full_service_meals.yoy_inflation_rate, color = 'red', label = 'Full Service Meals and Snacks')
plt.plot(limited_service_meals.yoy_inflation_rate, color = 'blue', label = 'Limited Service Meals and Snacks')
plt.plot(all_items.yoy_inflation_rate, color = 'green', label = 'All Items')

plt.title("Year over Year Change in Inflation Rate")
plt.xlabel("Date")
plt.ylabel("% Change")
plt.axhline(y=0, color='black', linestyle='--')

plt.tight_layout(pad=1)
plt.legend()
plt.show()

# %%
plt.plot(full_service_meals.yoy_inflation_rate, color = 'green', label = 'Full Service Meals and Snacks')
plt.plot(limited_service_meals.yoy_inflation_rate, color = 'blue', label = 'Limited Service Meals and Snacks')
plt.plot(food_away_from_home.yoy_inflation_rate, color = 'purple', label='Food Away from Home')

plt.title("Year over Year Change in Inflation Rate")
plt.xlabel("Date")
plt.ylabel("% Change")
plt.axhline(y=0, color='black', linestyle='--')

plt.tight_layout(pad=1)
plt.legend()
plt.show()

# %%
plt.plot(meats_fish_eggs.yoy_inflation_rate, color = 'red', label = 'Meats, Poultry, Fish, and Eggs')
plt.plot(fruits_veggies.yoy_inflation_rate, color = 'blue', label = 'Fruits and Vegetables')
plt.plot(cereal_bakery.yoy_inflation_rate, color = 'black', label = 'Cereals and Bakery Products')
plt.plot(full_service_meals.yoy_inflation_rate, color = 'orange', label = 'Full Service Meals and Snacks')
plt.plot(limited_service_meals.yoy_inflation_rate, color = 'purple', label = 'Limited Service Meals and Snacks')
plt.plot(food_at_home.yoy_inflation_rate, color = 'green', label = 'Food at Home')
plt.plot(food_away_from_home.yoy_inflation_rate, color = 'yellow', label = 'Food away from Home')

plt.title("Year over Year Change in Inflation Rate")
plt.xlabel("Date")
plt.ylabel("% Change")
plt.axhline(y=0, color='gray', linestyle='--')

plt.tight_layout(pad=1)
plt.legend()
plt.show()

# %%
plt.plot(all_items.yoy_inflation_rate, color = 'red', label = 'All Items')
plt.plot(food.yoy_inflation_rate, color = 'blue', label = 'Food')

plt.title("Year over Year Change in Inflation Rate")
plt.xlabel("Date")
plt.ylabel("% Change")
plt.axhline(y=0, color='black', linestyle='--')

plt.tight_layout(pad=1)
plt.legend()
plt.show()
